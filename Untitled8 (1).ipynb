# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import pandas as pd
import time

# Ruta a tu ChromeDriver
driver_path = "ruta/al/chromedriver"  # Cambia esto por la ruta a tu ChromeDriver
service = Service(driver_path)

# Configurar el navegador
driver = webdriver.Chrome(service=service)

# URL de la página con los datos de ingresos de GameStop
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
driver.get(url)

# Esperar unos segundos para que el contenido de la página se cargue
time.sleep(5)

# Obtener el contenido HTML de la página
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# Buscar la tabla de ingresos
tables = soup.find_all("table")
revenue_table = None

for table in tables:
    if "GameStop Quarterly Revenue" in str(table):  # Busca la tabla correcta
        revenue_table = table
        break

# Extraer los datos de la tabla
if revenue_table:
    rows = revenue_table.find_all("tr")
    revenue_data = []
    for row in rows:
        cols = row.find_all("td")
        revenue_data.append([col.text.strip() for col in cols])

    # Crear el DataFrame
    gme_revenue = pd.DataFrame(revenue_data, columns=["Date", "Revenue"])

    # Limpiar los datos
    gme_revenue = gme_revenue.dropna()  # Eliminar filas vacías
    gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(",", "").str.replace("$", "")
    gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"], errors="coerce")

    # Mostrar las últimas cinco filas
    print(gme_revenue.tail())
else:
    print("No se pudo extraer la tabla de ingresos.")

# Cerrar el navegador
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/common/driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: ruta/al/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[2], line 12
#       9 service = Service(driver_path)
#      11 # Configurar el navegador
# ---> 12 driver = webdriver.Chrome(service=service)
#      14 # URL de la página con los datos de ingresos de GameStop
#      15 url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
#
# ...

# %%
driver_path = "C:/ruta/a/chromedriver.exe"  # Cambia esta ruta por la correcta

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time

# Configurar el navegador con WebDriver Manager
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# URL de la página con los datos de ingresos de GameStop
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
driver.get(url)

# Esperar unos segundos para que el contenido de la página se cargue
time.sleep(5)

# Obtener el contenido HTML de la página
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# Buscar la tabla de ingresos
tables = soup.find_all("table")
revenue_table = None

for table in tables:
    if "GameStop Quarterly Revenue" in str(table):  # Busca la tabla correcta
        revenue_table = table
        break

# Extraer los datos de la tabla
if revenue_table:
    rows = revenue_table.find_all("tr")
    revenue_data = []
    for row in rows:
        cols = row.find_all("td")
        revenue_data.append([col.text.strip() for col in cols])

    # Crear el DataFrame
    gme_revenue = pd.DataFrame(revenue_data, columns=["Date", "Revenue"])

    # Limpiar los datos
    gme_revenue = gme_revenue.dropna()  # Eliminar filas vacías
    gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(",", "").str.replace("$", "")
    gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"], errors="coerce")

    # Mostrar las últimas cinco filas
    print(gme_revenue.tail())
else:
    print("No se pudo extraer la tabla de ingresos.")

# Cerrar el navegador
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[5], line 10
#       8 # Configurar el navegador con WebDriver Manager
#       9 service = Service(ChromeDriverManager().install())
# ---> 10 driver = webdriver.Chrome(service=service)
#      12 # URL de la página con los datos de ingresos de GameStop
#      13 url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
#
# File /opt/conda/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
# ...

# %%
import pandas as pd

# URL de la página
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

# Leer tablas de la página
tables = pd.read_html(url)

# Seleccionar la tabla correcta (ajusta el índice según sea necesario)
gme_revenue = tables[0]  # Cambia el índice si hay varias tablas

# Mostrar las últimas cinco filas
print(gme_revenue.tail())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4 url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
#       6 # Leer tablas de la página
# ----> 7 tables = pd.read_html(url)
#       9 # Seleccionar la tabla correcta (ajusta el índice según sea necesario)
#      10 gme_revenue = tables[0]  # Cambia el índice si hay varias tablas
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de la página con los datos
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

# Cabeceras para simular un navegador real
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

# Realizar la solicitud
response = requests.get(url, headers=headers)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")

    # Buscar la tabla de ingresos
    tables = soup.find_all("table")
    revenue_table = None

    for table in tables:
        if "GameStop Quarterly Revenue" in str(table):  # Encuentra la tabla correcta
            revenue_table = table
            break

    # Extraer los datos de la tabla
    if revenue_table:
        rows = revenue_table.find_all("tr")
        revenue_data = []
        for row in rows:
            cols = row.find_all("td")
            revenue_data.append([col.text.strip() for col in cols])

        # Crear el DataFrame
        gme_revenue = pd.DataFrame(revenue_data, columns=["Date", "Revenue"])

        # Limpiar los datos
        gme_revenue = gme_revenue.dropna()  # Eliminar filas vacías
        gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(",", "").str.replace("$", "")
        gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"], errors="coerce")

        # Mostrar las últimas cinco filas
        print(gme_revenue.tail())
    else:
        print("No se pudo encontrar la tabla de ingresos.")
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
#           Date  Revenue
# 59  2010-01-31     3524
# 60  2009-10-31     1835
# 61  2009-07-31     1739
# 62  2009-04-30     1981
# 63  2009-01-31     3492

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos de las acciones de Tesla
tesla_data = yf.download("TSLA", start="2020-01-01", end="2023-12-31")

# Función para graficar los datos
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Tesla Stock Price', linewidth=2)
    plt.title(title, fontsize=16)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Stock Price (USD)", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend(fontsize=12)
    plt.show()

# Llamar a la función para graficar
make_graph(tesla_data, "Tesla Stock Price (2020-2023)")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import yfinance as yf
# ----> 2 import matplotlib.pyplot as plt
#       4 # Descargar datos de las acciones de Tesla
#       5 tesla_data = yf.download("TSLA", start="2020-01-01", end="2023-12-31")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install yfinance matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 126.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 100.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 92.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 10.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos de las acciones de Tesla
tesla_data = yf.download("TSLA", start="2020-01-01", end="2023-12-31")

# Función para graficar los datos
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Tesla Stock Price', linewidth=2)
    plt.title(title, fontsize=16)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Stock Price (USD)", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend(fontsize=12)
    plt.show()

# Llamar a la función para graficar
make_graph(tesla_data, "Tesla Stock Price (2020-2023)")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
pip install yfinance matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Descargar datos de las acciones de GameStop
gme_data = yf.download("GME", start="2020-01-01", end="2023-12-31")

# Función para graficar los datos
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='GameStop Stock Price', linewidth=2, color='blue')
    plt.title(title, fontsize=16)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Stock Price (USD)", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend(fontsize=12)
    plt.show()

# Llamar a la función para graficar
make_graph(gme_data, "GameStop Stock Price (2020-2023)")
# Out:
# [*********************100%***********************]  1 of 1 completed
